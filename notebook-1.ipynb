# %%
from unstructured.partition.docx import partition_docx
file_path = "/home/naufal/file_extractor/source/docs/Kompilasi Tabel HC.docx"
with open(file_path, "rb") as file:
    elements = partition_docx(file=file)

# %%
for element in elements:
    print(type(element).__name__)
# Out:
# Text
# Text
# Text
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# Text
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# PageBreak
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# Text
# Text
# ListItem
# ListItem
# ListItem
# Text
# ListItem
# ListItem
# ListItem
# ListItem
# PageBreak
# ListItem
# ListItem
# Text
# Text
# ListItem
# ListItem
# ListItem
# ListItem
# Text
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# Text
# Text
# ListItem
# ListItem
# ListItem
# ListItem
# PageBreak
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# Text
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# PageBreak
# ListItem
# Text
# Text
# ListItem
# ListItem
# Text
# ListItem
# ListItem
# ListItem
# ListItem
# Text
# Text
# Text
# ListItem
# ListItem
# ListItem
# Text
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# PageBreak
# Text
# Text
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# PageBreak
# ListItem
# ListItem
# ListItem
# Text
# NarrativeText
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# Text
# NarrativeText
# ListItem
# PageBreak
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# Text
# Text
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# PageBreak
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# PageBreak
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
# ListItem
